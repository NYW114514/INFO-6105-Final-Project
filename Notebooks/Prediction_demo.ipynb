# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    confusion_matrix, 
    classification_report, 
    f1_score, 
    accuracy_score, 
    precision_score, 
    recall_score
)
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load test data
X_test = pd.read_csv('../Data/X_test.csv')
y_test = pd.read_csv('../Data/y_test.csv').squeeze()
company_names = X_test['company']
X_test = X_test.drop('company', axis=1)
print("Data Loaded")
print(f"Test set shape: {X_test.shape}")
print(f"Features: {list(X_test.columns)}")
print("\nTest data preview (first 10 rows):")
display(X_test.head(10))
# Out:
# Data Loaded
# Test set shape: (242, 9)
# Features: ['industry', 'stage', 'funds_raised', 'region', 'recency', 'events_deviation', 'recency_deviation', 'layoff_events_category', 'funds_raised_binned']
#
# Test data preview (first 10 rows):
#          industry     stage  funds_raised         region  recency  \
# 0  Transportation   Unknown          45.0  North America        5
# 1           Media  Post-IPO          77.0  North America        5
# 2      Healthcare  Post-IPO         172.0  North America        2
# 3         Finance  Series E         321.0         Europe        3
# 4       Education  Series D         483.0  North America        3
# 5  Transportation   Unknown          86.0  North America        1
# 6            Food  Series C         127.0  North America        0
# 7           Sales  Post-IPO          65.0  North America        5
# 8            Food  Series D         711.0  North America        2
# 9         Finance  Series C         142.0  North America        3
#
#    events_deviation  recency_deviation layoff_events_category  \
# 0         -0.458333           2.055556                   once
# 1         -0.435897           2.333333                   once
# 2         -0.260417          -0.593750                   once
# 3          0.709877          -0.006173                  twice
# 4         -0.527778           0.138889                   once
# 5         -0.458333          -1.944444                   once
# 6         -0.378788          -2.909091                   once
# 7          3.583333           2.583333              four_plus
# 8         -0.378788          -0.909091                   once
# 9         -0.290123          -0.006173                   once
#
#   funds_raised_binned
# 0                tiny
# 1               small
# 2              medium
# 3              medium
# 4               large
# 5               small
# 6               small
# 7               small
# 8               large
# 9               small

# %%
# Encode categorical features
X_test_encoded = X_test.copy()

for col in ['industry', 'stage', 'region', 'layoff_events_category', 'funds_raised_binned']:
    le = LabelEncoder()
    le.fit(X_test[col])
    X_test_encoded[col] = le.transform(X_test[col])

print("Encoding complete.")
print(f"Encoded test shape: {X_test_encoded.shape}")
# Out:
# Encoding complete.
# Encoded test shape: (242, 9)

# %%
# Load best model (XGBoost)
model = joblib.load('../Model/xgboost_model.pkl')

# Make predictions
y_pred = model.predict(X_test_encoded)
y_pred_proba = model.predict_proba(X_test_encoded)[:, 1]
print("Prediction complete.")
# Out:
# Prediction complete.

# %%
predictions_df = pd.DataFrame({
    'Company': company_names.values,
    'Actual': y_test.values,
    'Predicted': y_pred,
    'Probability': y_pred_proba
})

predictions_df['Correct'] = predictions_df['Actual'] == predictions_df['Predicted']

# %%
# Show random 20 predictions for demonstration
np.random.seed(42)
random_indices = np.random.choice(len(predictions_df), 20, replace=False)
sample_predictions = predictions_df.iloc[random_indices].sort_index()

print("Random Predictions Sample (20 samples):")

def style_predictions(df):
    styled = df.style
    
    styled = styled.applymap(
        lambda x: 'background-color: skyblue' if x == True else 'background-color: lightcoral',
        subset=['Correct']
    )
    
    def prob_color(val):
        if val > 0.7:
            return 'background-color: magenta; color: white'
        elif 0.5 <= val <= 0.7:
            return 'background-color: yellow'
        elif val < 0.5:
            return 'background-color: lightgreen'
        else:
            return ''
    
    styled = styled.applymap(prob_color, subset=['Probability'])
    
    return styled.set_properties(**{'text-align': 'center'})

display(style_predictions(sample_predictions))
# Out:
# Random Predictions Sample (20 samples):
# <style type="text/css">
# #T_2d704_row0_col0, #T_2d704_row0_col1, #T_2d704_row0_col2, #T_2d704_row1_col0, #T_2d704_row1_col1, #T_2d704_row1_col2, #T_2d704_row2_col0, #T_2d704_row2_col1, #T_2d704_row2_col2, #T_2d704_row3_col0, #T_2d704_row3_col1, #T_2d704_row3_col2, #T_2d704_row4_col0, #T_2d704_row4_col1, #T_2d704_row4_col2, #T_2d704_row5_col0, #T_2d704_row5_col1, #T_2d704_row5_col2, #T_2d704_row6_col0, #T_2d704_row6_col1, #T_2d704_row6_col2, #T_2d704_row7_col0, #T_2d704_row7_col1, #T_2d704_row7_col2, #T_2d704_row8_col0, #T_2d704_row8_col1, #T_2d704_row8_col2, #T_2d704_row9_col0, #T_2d704_row9_col1, #T_2d704_row9_col2, #T_2d704_row10_col0, #T_2d704_row10_col1, #T_2d704_row10_col2, #T_2d704_row11_col0, #T_2d704_row11_col1, #T_2d704_row11_col2, #T_2d704_row12_col0, #T_2d704_row12_col1, #T_2d704_row12_col2, #T_2d704_row13_col0, #T_2d704_row13_col1, #T_2d704_row13_col2, #T_2d704_row14_col0, #T_2d704_row14_col1, #T_2d704_row14_col2, #T_2d704_row15_col0, #T_2d704_row15_col1, #T_2d704_row15_col2, #T_2d704_row16_col0, #T_2d704_row16_col1, #T_2d704_row16_col2, #T_2d704_row17_col0, #T_2d704_row17_col1, #T_2d704_row17_col2, #T_2d704_row18_col0, #T_2d704_row18_col1, #T_2d704_row18_col2, #T_2d704_row19_col0, #T_2d704_row19_col1, #T_2d704_row19_col2 {
#   text-align: center;
# }
# #T_2d704_row0_col3, #T_2d704_row1_col3, #T_2d704_row2_col3, #T_2d704_row6_col3, #T_2d704_row7_col3, #T_2d704_row8_col3, #T_2d704_row9_col3, #T_2d704_row11_col3, #T_2d704_row12_col3, #T_2d704_row17_col3, #T_2d704_row18_col3, #T_2d704_row19_col3 {
#   background-color: lightgreen;
#   text-align: center;
# }
# #T_2d704_row0_col4, #T_2d704_row1_col4, #T_2d704_row3_col4, #T_2d704_row4_col4, #T_2d704_row5_col4, #T_2d704_row6_col4, #T_2d704_row7_col4, #T_2d704_row8_col4, #T_2d704_row9_col4, #T_2d704_row10_col4, #T_2d704_row11_col4, #T_2d704_row12_col4, #T_2d704_row13_col4, #T_2d704_row14_col4, #T_2d704_row15_col4, #T_2d704_row16_col4, #T_2d704_row17_col4, #T_2d704_row18_col4, #T_2d704_row19_col4 {
#   background-color: skyblue;
#   text-align: center;
# }
# #T_2d704_row2_col4 {
#   background-color: lightcoral;
#   text-align: center;
# }
# #T_2d704_row3_col3, #T_2d704_row5_col3, #T_2d704_row10_col3, #T_2d704_row14_col3, #T_2d704_row16_col3 {
#   background-color: yellow;
#   text-align: center;
# }
# #T_2d704_row4_col3, #T_2d704_row13_col3, #T_2d704_row15_col3 {
#   background-color: magenta;
#   color: white;
#   text-align: center;
# }
# </style>
# <table id="T_2d704">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d704_level0_col0" class="col_heading level0 col0" >Company</th>
#       <th id="T_2d704_level0_col1" class="col_heading level0 col1" >Actual</th>
#       <th id="T_2d704_level0_col2" class="col_heading level0 col2" >Predicted</th>
#       <th id="T_2d704_level0_col3" class="col_heading level0 col3" >Probability</th>
#       <th id="T_2d704_level0_col4" class="col_heading level0 col4" >Correct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d704_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_2d704_row0_col0" class="data row0 col0" >Restaurant365</td>
#       <td id="T_2d704_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_2d704_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_2d704_row0_col3" class="data row0 col3" >0.312574</td>
#       <td id="T_2d704_row0_col4" class="data row0 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_2d704_row1_col0" class="data row1 col0" >Embroker</td>
#       <td id="T_2d704_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2d704_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_2d704_row1_col3" class="data row1 col3" >0.259040</td>
#       <td id="T_2d704_row1_col4" class="data row1 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row2" class="row_heading level0 row2" >15</th>
#       <td id="T_2d704_row2_col0" class="data row2 col0" >Autograph</td>
#       <td id="T_2d704_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_2d704_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_2d704_row2_col3" class="data row2 col3" >0.283528</td>
#       <td id="T_2d704_row2_col4" class="data row2 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_2d704_row3_col0" class="data row3 col0" >Guild</td>
#       <td id="T_2d704_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_2d704_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_2d704_row3_col3" class="data row3 col3" >0.581372</td>
#       <td id="T_2d704_row3_col4" class="data row3 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row4" class="row_heading level0 row4" >45</th>
#       <td id="T_2d704_row4_col0" class="data row4 col0" >Intuit</td>
#       <td id="T_2d704_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_2d704_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_2d704_row4_col3" class="data row4 col3" >0.849770</td>
#       <td id="T_2d704_row4_col4" class="data row4 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row5" class="row_heading level0 row5" >66</th>
#       <td id="T_2d704_row5_col0" class="data row5 col0" >Glisser</td>
#       <td id="T_2d704_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_2d704_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_2d704_row5_col3" class="data row5 col3" >0.580257</td>
#       <td id="T_2d704_row5_col4" class="data row5 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row6" class="row_heading level0 row6" >82</th>
#       <td id="T_2d704_row6_col0" class="data row6 col0" >Atlas</td>
#       <td id="T_2d704_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_2d704_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_2d704_row6_col3" class="data row6 col3" >0.223981</td>
#       <td id="T_2d704_row6_col4" class="data row6 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row7" class="row_heading level0 row7" >113</th>
#       <td id="T_2d704_row7_col0" class="data row7 col0" >Deepwatch</td>
#       <td id="T_2d704_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_2d704_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_2d704_row7_col3" class="data row7 col3" >0.173749</td>
#       <td id="T_2d704_row7_col4" class="data row7 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row8" class="row_heading level0 row8" >127</th>
#       <td id="T_2d704_row8_col0" class="data row8 col0" >Shogun</td>
#       <td id="T_2d704_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_2d704_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_2d704_row8_col3" class="data row8 col3" >0.259571</td>
#       <td id="T_2d704_row8_col4" class="data row8 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row9" class="row_heading level0 row9" >150</th>
#       <td id="T_2d704_row9_col0" class="data row9 col0" >Proofpoint</td>
#       <td id="T_2d704_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_2d704_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_2d704_row9_col3" class="data row9 col3" >0.191310</td>
#       <td id="T_2d704_row9_col4" class="data row9 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row10" class="row_heading level0 row10" >152</th>
#       <td id="T_2d704_row10_col0" class="data row10 col0" >Deliv</td>
#       <td id="T_2d704_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_2d704_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_2d704_row10_col3" class="data row10 col3" >0.502109</td>
#       <td id="T_2d704_row10_col4" class="data row10 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2d704_level0_row11" class="row_heading level0 row11" >161</th>
#       <td id="T_2d704_row11_col0" class="data row11 col0" >SonderMind</td>
#       <td id="T_2d704_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_2d704_row11_col2" class="data row11 col2" >0</td>
#       <td id="T_2d7

# %%
print("Predictions Summary:")
print(f"Total predictions: {len(predictions_df)}")
print(f"Correct: {predictions_df['Correct'].sum()}")
print(f"Incorrect: {(~predictions_df['Correct']).sum()}")
print(f"Accuracy: {predictions_df['Correct'].mean():.2%}")
# Out:
# Predictions Summary:
# Total predictions: 242
# Correct: 190
# Incorrect: 52
# Accuracy: 78.51%

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

print("Confusion Matrix:")
print(f"TP (True Positive)   = {tp}  → correctly identified high-risk companies")
print(f"FP (False Positive)  = {fp}  → predicted high-risk but actually safe")
print(f"FN (False Negative)  = {fn}  → predicted safe but actually high-risk")
print(f"TN (True Negative)   = {tn}  → correctly identified safe companies")

print("\nDetailed Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Low Risk', 'High Risk']))

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Key Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Confusion Matrix:
# TP (True Positive)   = 64  → correctly identified high-risk companies
# FP (False Positive)  = 31  → predicted high-risk but actually safe
# FN (False Negative)  = 21  → predicted safe but actually high-risk
# TN (True Negative)   = 126  → correctly identified safe companies
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#     Low Risk       0.86      0.80      0.83       157
#    High Risk       0.67      0.75      0.71        85
#
#     accuracy                           0.79       242
#    macro avg       0.77      0.78      0.77       242
# weighted avg       0.79      0.79      0.79       242
#
# Key Metrics:
# Accuracy: 0.7851
# Precision: 0.6737
# Recall: 0.7529
# F1-Score: 0.7111

# %%
# FP high means model is over-sensitive and flags safe companies as risky.
# FN high means model misses truly high-risk companies.

# %%
# Accuracy 0.7851: Model correctly classifies 78.5% of all companies
# Precision 0.6737: Of companies predicted as high-risk, 67% are actually high-risk (33% false alarms)
# Recall 0.7529: Model catches 74.1% of actual high-risk companies (misses 24.7%)
# F1-Score 0.7111: Balanced measure of model performance
# 
# Business Insight: The model reliably identifies ~3/4 of high-risk companies with moderate false positives,
# making it useful for investors to flag potentially unstable companies for further investigation.
